# %% [markdown]
# ## Verifica finale di apprendimento
#
# la verifica è composta da 30 esercizi suddivisi in celle del notebook.

# %%
# non toccare questa cella
# %load_ext ipython_pytest

# %% [markdown]
# ### 1) test funzioni basilari di operazione tra numeri

# %%
# %%pytest -v
# import pytest
#
#
# # implementare il ritorno di funzione con il risultato
# # della somma dei 2 parametri a e b
# def somma(a, b):
#     return a + b
#
#
# #  implementare il ritorno con la sottrazione tra i 2 parametri
# def sottrazione(a, b):
#     return a - b
#
#
# def moltiplicazione(a, b):
#     return a * b
#
#
# def divisione(a, b):
#     return a / b
#
#
# def potenza(a, b):
#     return a ** b
#
#
# ###############################################################################
# ###############################################################################
# #              TESTING - non toccare                                          #
# ###############################################################################
# @pytest.mark.parametrize("a,b,needle", [
#     (1, 1, 2),
#     (2, 2, 4),
#     (10, 10, 20),
#     (20, 25.2, 45.2)
# ])
# def test_somma(a, b, needle):
#     assert somma(a, b) == needle
#
#
# @pytest.mark.parametrize("a,b,needle", [
#     (1, 1, 0),
#     (10, 10, 0),
#     (6, 3, 3),
#     (27, 22, 5)
# ])
# def test_sottrazione(a, b, needle):
#     assert sottrazione(a,  b) == needle
#
#
# @pytest.mark.parametrize("a,b,needle", [
#     (1, 1, 1),
#     (10, 10, 100),
#     (3, 3, 9),
#     (0, 3, 0),
# ])
# def test_moltiplicazione(a, b, needle):
#     assert moltiplicazione(a, b) == needle
#
# @pytest.mark.parametrize("a,b,needle", [
#     (1, 1, 1),
#     (10, 10, 1),
#     (9, 3, 3),
#     (20, 5, 4),
# ])
# def test_divisione(a, b, needle):
#     assert divisione(a, b) == needle
#
# def test_divisione_per_zero_raise_exception():
#     with pytest.raises(ZeroDivisionError):
#         divisione(1,0)
#
# @pytest.mark.parametrize("a,b,needle", [
#     (2, 2, 4),
#     (10, 2, 100),
#     (5, 2, 25),
#     (4, 3, 64)
# ])
# def test_potenza(a, b, needle):
#     assert potenza(a, b) == needle
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.7.4, pytest-5.3.4, py-1.8.1, pluggy-0.13.1 -- /jupyter/.venv/bin/python3.7
# cachedir: .pytest_cache
# rootdir: /tmp/tmp2h6cnk3x
# collecting ... collected 21 items
#
# _ipytesttmp.py::test_somma[1-1-2] PASSED                                 [  4%]
# _ipytesttmp.py::test_somma[2-2-4] PASSED                                 [  9%]
# _ipytesttmp.py::test_somma[10-10-20] PASSED                              [ 14%]
# _ipytesttmp.py::test_somma[20-25.2-45.2] PASSED                          [ 19%]
# _ipytesttmp.py::test_sottrazione[1-1-0] PASSED                           [ 23%]
# _ipytesttmp.py::test_sottrazione[10-10-0] PASSED                         [ 28%]
# _ipytesttmp.py::test_sottrazione[6-3-3] PASSED                           [ 33%]
# _ipytesttmp.py::test_sottrazione[27-22-5] PASSED                         [ 38%]
# ...

# %% [markdown]
# ### 2) string slicing

# %%
# %%pytest -v
# import pytest
#
# # modificare le seguenti funzioni per far eseguire i test con successo
#
# def ritorna_primo_carattere(string):
#     return string[0]
#
# def ritorna_ultimo_carattere(string):
#     return string[-1]
#
# def ritorna_primi_tre_caratteri(string):
#     return string[:3]
#
# def ritorna_stringa_senza_primi_tre_caratteri(string):
#     return string[3:]
#
# def ritorna_secondo_e_terzo_carattere(string):
#     return string[1:3]
#
# ################################################################################################
# ################################################################################################
# #              TESTING - non toccare                                                           #
# ################################################################################################
# @pytest.mark.parametrize("a,needle", [
#     ("ciao", "c"), ("primo", "p"), ("0string", "0")
# ])
# def test_ritorna_primo_carattere(a, needle):
#     assert ritorna_primo_carattere(a) == needle
#
# @pytest.mark.parametrize("a,needle", [
#     ("ciao", "o"), ("primo", "o"), ("0string", "g")
# ])
# def test_ritorna_ultimo_carattere(a, needle):
#     assert ritorna_ultimo_carattere(a) == needle
#
# @pytest.mark.parametrize("a,needle", [
#     ("ciao", "cia"), ("primo", "pri"), ("0string", "0st")
# ])
# def test_ritorna_primi_tre_caratteri(a, needle):
#     assert ritorna_primi_tre_caratteri(a) == needle
#
# @pytest.mark.parametrize("a,needle", [
#     ("ciao", "o"), ("primo", "mo"), ("0string", "ring")
# ])
# def test_ritorna_stringa_senza_primi_tre_caratteri(a, needle):
#     assert ritorna_stringa_senza_primi_tre_caratteri(a) == needle
#
# @pytest.mark.parametrize("a,needle", [
#     ("ciao", "ia"), ("primo", "ri"), ("0string", "st")
# ])
# def test_ritorna_secondo_e_terzo_carattere(a, needle):
#     assert ritorna_secondo_e_terzo_carattere(a) == needle
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.7.4, pytest-5.3.4, py-1.8.1, pluggy-0.13.1 -- /jupyter/.venv/bin/python3.7
# cachedir: .pytest_cache
# rootdir: /tmp/tmp9od86agm
# collecting ... collected 15 items
#
# _ipytesttmp.py::test_ritorna_primo_carattere[ciao-c] PASSED              [  6%]
# _ipytesttmp.py::test_ritorna_primo_carattere[primo-p] PASSED             [ 13%]
# _ipytesttmp.py::test_ritorna_primo_carattere[0string-0] PASSED           [ 20%]
# _ipytesttmp.py::test_ritorna_ultimo_carattere[ciao-o] PASSED             [ 26%]
# _ipytesttmp.py::test_ritorna_ultimo_carattere[primo-o] PASSED            [ 33%]
# _ipytesttmp.py::test_ritorna_ultimo_carattere[0string-g] PASSED          [ 40%]
# _ipytesttmp.py::test_ritorna_primi_tre_caratteri[ciao-cia] PASSED        [ 46%]
# _ipytesttmp.py::test_ritorna_primi_tre_caratteri[primo-pri] PASSED       [ 53%]
# ...

# %% [markdown]
# ### 3) verifica condizionali

# %%
# %%pytest -v
# import pytest
#
# # modificare le seguenti funzioni per far eseguire i test con successo
#
# def maggiore_di_uno(value) -> bool:
#     # ritorna un valore booleano (true se il valore e' maggiore di uno, false se non lo e')
#     #... code
#     return value > 1
#
#
# def minore_di_uno(value) -> bool:
#     # ritorna un valore booleano (true se il valore e' minore di uno, false se lo e')
#     #... code
#     return value < 1
#
#
# def carattere_in_stringa(char: str, search_string: str) -> bool:
#     """
#     verifica se un carattere è contenuto  in una stringa.
#     param char: carattere da cercare
#     param search_string: stringa in cui ricercare il carattere
#
#     esempio: o è contenuta in ciao, k non è contenuta in prova
#     """
#     # ritorna un  valore booleano (true se il carattere(char) e' contenuto nella stringa(search_string) )
#     return char in search_string
#
#
# def numero_pari(number: int) -> bool:
#     """
#     verifica  se il numero passato come argomento è pari
#     """
#     return number % 2 == 0
#
#
# def numero_dispari(number: int) -> bool:
#     """
#     verifica  se il numero passato come argomento è dispari
#     """
#     return not numero_pari(number)
#
#
# def conteggio_dolci(persone: int,
#                     dolci_disponibili: int,
#                     numero_minimo_dolci: int = 3) -> bool:
#     """
#     la funzione ci  permette di verificare se i  dolci a nostra disposizione sono  sufficienti rispetto agli invitati
#     ipotizzando che ogni  invitato  mangia  3 dolci.
#
#     ## parameter ##
#     param persone: numero di invitati alla festa
#     param dolci_disponibili: numero  di dolci disponibili
#     param numero_minimo_dolci: rappresenta il numero minimo di dolci che devono essere disponibili
#
#     es:
#     10 persone , 30 dolci disponibili , 3 numero minimo  == true (i dolci sono sufficenti per la riuscita della festa)
#     10 persone , 25 dolci disponibili , 3 numero minimo  == false (i dolci non bastano)
#
#     """
#     # la funzione deve verificare se i dolci disponibili sono sufficienti per
#     # le persone  invitate alla festa.
#     # il numero minimo di dolci per ogni persona è pari a 3 ma è possibile personalizzarlo passando il parametro numero_minimo=N
#     return ( dolci_disponibili / 3 ) >= persone
#
#
# def ascensore_troppo_carico(persone: int,
#                             carico_consigliato: int = 1200,
#                             peso_medio: int = 80,
#                             extra: int = 10) -> bool:
#     """
#     param persone: numero di persone attualmente presenti  in ascensore
#     param carico_consigliato: peso massimo in kg
#     param peso_medio: valore che  indica il peso medio di ogni persona
#     param extra: percentuale di tolleranza di carico ulteriore rispetto al carico_consigliato
#
#     es:
#     10 persone
#     1200 carico consigliato
#     80 ppeso medio
#     10% tolleranza extra
#     carico massimo sopportabile:  1200 + 10% (1320kg carico massimo)
#     ascensore_sovraccarico? no (80kg per persona, 10 persone, max sopportabili 1320)
#
#     calcolare se il peso totale  delle persone a bordo dell'ascensore sia  superiore al carico  massimo sopportabile
#     es: 2000kg peso max, 2000kg attuali = False
#     2000kg peso max, 1999kg attuali = True
#     """
#     peso_max = carico_consigliato  + ( carico_consigliato / 100 * extra)
#     return (persone * peso_medio) >= peso_max
#
#
#
# def benzina_sufficiente(km_per_litro: int, km_da_percorrere: int, litri_disponibili: int) -> bool:
#     """
#     param km_per_litro: i kilometri  che la macchina può percorrere con un litro di benzina
#     param km_da_percorrere: la distanza da percorrere
#     param litri_disponibili: litri di benzina disponibili nella macchina
#     """
#     return km_per_litro * litri_disponibili >= km_da_percorrere
#
#
# def anno_bisestile(anno: int) -> bool:
#     """
#     verificare se si tratta di un anno bisestile o meno
#
#     param anno: l'anno da verificare
#
#     Per vedere se un anno è bisestile dobbiamo dividerlo per 400;
#     se è divisibile allora è sicuramente un anno bisestile;
#     altrimenti saranno bisestili solo quegli anni che si possono dividere per 4 ma non per 100.
#     """
#     return anno % 400 == 0 or ((anno % 4 == 0) and (not anno % 100 == 0) )
#
# ################################################################################################
# ################################################################################################
# #              TESTING - non toccare                                                           #
# ################################################################################################
# @pytest.mark.parametrize("a,needle", [
#     (1, False), (2, True), (0, False), (1.1, True)
# ])
# def test_maggiore_di_uno(a, needle):
#     assert maggiore_di_uno(a) == needle
#
# @pytest.mark.parametrize("a,needle", [
#     (1, False), (2, False), (0, True), (1.1, False)
# ])
# def test_minore_di_uno(a, needle):
#     assert minore_di_uno(a) == needle
#
# @pytest.mark.parametrize("a,b,needle", [
#     ("o", "ciao", True),("a", "prove", False),("k", "key", True),
# ])
# def test_carattere_in_stringa(a, b, needle):
#     assert carattere_in_stringa(a, b) == needle
#
# @pytest.mark.parametrize("a,needle", [
#     (1, False), (2, True), (10, True), (1.1, False)
# ])
# def test_numero_pari(a, needle):
#     assert numero_pari(a) == needle
#
# @pytest.mark.parametrize("a,needle", [
#     (1, True), (2, False), (10, False), (3, True)
# ])
# def test_numero_dispari(a, needle):
#     assert numero_dispari(a) == needle
#
# @pytest.mark.parametrize("a,b,needle", [
#     (10, 32, True), (15, 30, False), (7, 21, True)
# ])
# def test_conteggio_dolci(a, b, needle):
#     assert conteggio_dolci(a, b) == needle
#
# @pytest.mark.parametrize("persone,carico,extra,needle", [
#     (10, 800, 10, False), (13, 800, 10, True), (13, 1000, 5, False)
# ])
# def test_ascensore_troppo_carico(persone, carico, extra, needle):
#     assert ascensore_troppo_carico(persone=persone, carico_consigliato=carico, extra=extra) == needle
#
# @pytest.mark.parametrize("a,b,c,needle", [
#     (25, 800, 30, False), (25, 1000, 45, True), (25, 50, 50, True)
# ])
# def test_benzina_sufficiente(a, b, c, needle):
#     assert benzina_sufficiente(a, b, c) == needle
#
# @pytest.mark.parametrize("a,needle", [
#     (2000, True), (2001, False), (2004, True), (2016, True), (1000, False)
# ])
# def test_anno_bisestile(a, needle):
#     assert anno_bisestile(a) == needle
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.7.4, pytest-5.3.4, py-1.8.1, pluggy-0.13.1 -- /jupyter/.venv/bin/python3.7
# cachedir: .pytest_cache
# rootdir: /tmp/tmp89n8__4d
# collecting ... collected 33 items
#
# _ipytesttmp.py::test_maggiore_di_uno[1-False] PASSED                     [  3%]
# _ipytesttmp.py::test_maggiore_di_uno[2-True] PASSED                      [  6%]
# _ipytesttmp.py::test_maggiore_di_uno[0-False] PASSED                     [  9%]
# _ipytesttmp.py::test_maggiore_di_uno[1.1-True] PASSED                    [ 12%]
# _ipytesttmp.py::test_minore_di_uno[1-False] PASSED                       [ 15%]
# _ipytesttmp.py::test_minore_di_uno[2-False] PASSED                       [ 18%]
# _ipytesttmp.py::test_minore_di_uno[0-True] PASSED                        [ 21%]
# _ipytesttmp.py::test_minore_di_uno[1.1-False] PASSED                     [ 24%]
# ...

# %% [markdown]
# ### 3) Cicli (loops)

# %%
# %%pytest -v
# import pytest
# import datetime
#
# ## modificare da  qui
#
# def conta_caratteri(string: str) -> int:
#     """
#     conteggio caratteri che compongono la stringa
#
#     param string: la stringa da sottoporre a conteggio caratteri
#     return int: un numero intero con il numero di caratteri presenti nella stringa
#
#     hint: usare ciclo for
#     """
#     return len(string)
#
#
# def contrario(string: str) -> str:
#     """
#     la funzione ritorna la stringa al contrario (es: ciao -> oaic)
#
#     param string: la stringa da analizzare
#     return str: la stringa da ritornare
#     hint: scorrere la stringa dalla fine all'inizio
#     """
#     if len(string) == 1:
#         return string
#
#     counter = len(string) - 1
#     newstring = ""
#     while counter >= 0:
#         newstring += string[counter]
#         counter -= 1
#     return newstring
#
# def eta_attuale(anno_nascita: int) -> int:
#     """
#     calcolare gli anni di una persona partendo dall'anno di nascita.
#
#     param anno_nascita: numero intero es. 1950
#     return int: anni della persona
#
#     es: anno corrente: 2020, anno nascita: 1950 , 70 anni
#     """
#     anno_corrente = datetime.datetime.now().year
#     return anno_corrente - anno_nascita
#
#
# def conteggio_numeri_pari(lista: list) -> int:
#     """
#     calcolare gli anni di una persona partendo dall'anno di nascita.
#
#     param lista: lista di numeri interi
#     return int: conteggio degli elementi pari nella lista
#     hint:
#         - numero pari se (n % 2 == 0)
#         - utilizzare un contatore
#
#     es: [1,2,3,4] contiene 2 numeri pari
#
#     """
#     count = 0
#     for item in lista:
#         if item % 2 == 0:
#             count += 1
#     return count
#
#
# def temperature_superiori_di(lista: list,
#                                        temperatura_max: int) -> list:
#     """
#     ritornare una lista con i valori di temperatura che hanno superato o sono equivalenti al valore massimo
#
#     param lista: lista di rilevazioni
#     param temperatura_max: valore massimo della temperatura
#     return list: lista con gli elementi che hanno superato o sono pari al volore massimmo
#
#     hint:
#         - utilizzare una nuova lista vuota
#
#     es:
#         lista: [30,31,31,30,29,29]
#         valore_max: 30
#         return: [30,31,31,30]
#     """
#     ret = []
#     for item in lista:
#         if item >= temperatura_max:
#             ret.append(item)
#     return ret
#
#
#
# ################################################################################################
# ################################################################################################
# #              TESTING - non toccare                                                           #
# ################################################################################################
# ################################################################################################
# @pytest.mark.parametrize("a", [
#     ("ciao"), ("prova"), (""), ("stringalungalungalungalunga")
# ])
# def test_conta_caratteri(a):
#     assert type(a) == str
#     assert conta_caratteri(a) == len(a)
#
# @pytest.mark.parametrize("a,needle", [
#     ("ciao", "oaic"), ("10", "01"), ("prova", "avorp"), ("k", "k")
# ])
# def test_contrario(a, needle):
#     assert contrario(a) == needle
#
# @pytest.mark.parametrize("a,needle", [
#     (1950, datetime.datetime.now().year - 1950),
#     (2000, datetime.datetime.now().year - 2000),
#     (1927, datetime.datetime.now().year - 1927),
#     (2019, datetime.datetime.now().year - 2019)
# ])
# def test_eta_attuale(a, needle):
#     assert eta_attuale(a) == needle
#
# @pytest.mark.parametrize("a, needle", [
#     ([1,2,3,4], 2)
# ])
# def test_conteggio_numeri_pari(a, needle):
#     assert conteggio_numeri_pari(a) == needle
#
# @pytest.mark.parametrize("a,b,needle", [
#     ([30,30,31,31,29,29], 30, [30,30,31,31]),
#     ([29,30,31,31,29,29], 30, [30,31,31]),
#     ([10,10,0,0,0,0], 11, []),
#     ([10,10,0,0,0,0], 9, [10,10]),
# ])
# def test_temperature_superiori_di(a, b, needle):
#     assert temperature_superiori_di(a, b) == needle
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.7.4, pytest-5.3.4, py-1.8.1, pluggy-0.13.1 -- /jupyter/.venv/bin/python3.7
# cachedir: .pytest_cache
# rootdir: /tmp/tmpvbi7cz_g
# collecting ... collected 17 items
#
# _ipytesttmp.py::test_conta_caratteri[ciao] PASSED                        [  5%]
# _ipytesttmp.py::test_conta_caratteri[prova] PASSED                       [ 11%]
# _ipytesttmp.py::test_conta_caratteri[] PASSED                            [ 17%]
# _ipytesttmp.py::test_conta_caratteri[stringalungalungalungalunga] PASSED [ 23%]
# _ipytesttmp.py::test_contrario[ciao-oaic] PASSED                         [ 29%]
# _ipytesttmp.py::test_contrario[10-01] PASSED                             [ 35%]
# _ipytesttmp.py::test_contrario[prova-avorp] PASSED                       [ 41%]
# _ipytesttmp.py::test_contrario[k-k] PASSED                               [ 47%]
# ...

# %% [markdown]
# ### 4) Funzioni

# %%
# %%pytest -v
# import pytest

# %% [markdown]
# ### 5) Programmazione ad oggetti

# %% [markdown]
# ### X) Programmazione ad oggetti - ereditarietà

# %%
# %%pytest -v
# import pytest
#
# """
# modificare il seguente listato per soddisfare i casi di test definitis
# """
#
# class Vehicle:
#
#     ENGINE_STOPPED = 0
#     ENGINE_STARTED = 1
#     ENGINE_DAMAGED = 2
#
#     def __init__(self, price):
#         self.brand = self.__class__.__bases__[0].__name__
#         self.model = self.__class__.__name__
#         self.price = price
#         self.engine = self.ENGINE_STOPPED
#
#     def beep(self):
#         print("beeep!")
#
#     def engine_started(self) -> bool:
#         return self.engine == self.ENGINE_STARTED
#
#     def engine_start(self):
#         if not self.engine_started():
#             self.engine = self.ENGINE_STARTED
#
#     def engine_stop(self):
#         if self.engine_started():
#             self.engine = self.ENGINE_STOPPED
#
# class Car(Vehicle):
#     pass
#
# class Truck(Vehicle):
#     pass
#
# # brand
# """
# Brand è la classe principale che identifica il costruttore  di auto
# """
# class Brand:
#     pass
#
# # modificare la dichiarazione per estendere brand
# class Mercedes(Brand):
#     pass
#
# class Fiat(Brand):
#     pass
#
# class AlfaRomeo(Brand):
#     pass
#
# """
# modelli di  auto
#     creare i modelli di auto:
#     - Mercedes
#         - ClasseA
#         - ClasseB
#     - Fiat
#         - Tipo
#         - Cinquecento
#     - AlfaRomeo
#         - Giulia
#         - Giulietta
#
#     *esempio*: ClasseA deve estendere Mercedes e Car in quanto si tratta di una macchina
# """
# # auto mercedes
# class ClasseA(Mercedes, Car):
#     pass
#
# class ClasseB(Mercedes, Car):
#     pass
#
# class Tipo(Fiat, Car):
#     pass
#
# class Cinquecento(Fiat, Car):
#     pass
#
# class Giulia(AlfaRomeo, Car):
#     pass
#
# class Giulietta(AlfaRomeo, Car):
#     pass
# # implementare i modelli mancanti
# # ...
#
#
#
#
# ################################################################################################
# ################################################################################################
# #              TESTING - non toccare                                                           #
# ################################################################################################
# ################################################################################################
#
# @pytest.mark.parametrize("classname,parent,nestedParent", [
#     ("ClasseA", "Mercedes", "Car"),
#     ("ClasseB", "Mercedes", "Car"),
#     ("Tipo", "Fiat", "Car"),
#     ("Cinquecento", "Fiat", "Car"),
#     ("Giulia", "AlfaRomeo", "Car"),
#     ("Giulietta", "AlfaRomeo", "Car"),
# ])
# def test_models(classname, parent, nestedParent):
#     assert classname in  globals()
#     clsname = globals()[classname]
#     classess = [x.__name__ for x in clsname(0).__class__.__bases__]
#     assert sorted(classess) == sorted([parent, nestedParent])
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.7.4, pytest-5.3.4, py-1.8.1, pluggy-0.13.1 -- /jupyter/.venv/bin/python3.7
# cachedir: .pytest_cache
# rootdir: /tmp/tmpfr5kkpg6
# collecting ... collected 6 items
#
# _ipytesttmp.py::test_models[ClasseA-Mercedes-Car] PASSED                 [ 16%]
# _ipytesttmp.py::test_models[ClasseB-Mercedes-Car] PASSED                 [ 33%]
# _ipytesttmp.py::test_models[Tipo-Fiat-Car] PASSED                        [ 50%]
# _ipytesttmp.py::test_models[Cinquecento-Fiat-Car] PASSED                 [ 66%]
# _ipytesttmp.py::test_models[Giulia-AlfaRomeo-Car] PASSED                 [ 83%]
# _ipytesttmp.py::test_models[Giulietta-AlfaRomeo-Car] PASSED              [100%]
#
# ============================== 6 passed in 0.06s ===============================
